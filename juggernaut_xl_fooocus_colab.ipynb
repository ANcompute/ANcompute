# %% [markdown]
# <a href="https://colab.research.google.com/github/ANcompute/ANcompute/blob/main/juggernaut_xl_fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Gỡ sạch các phiên bản lỗi do đoạn code cũ cài vào
# !pip uninstall -y cupy-cuda12x cupy numpy rembg pymatting

# 2. Cài đặt lại cặp thư viện chuẩn khớp hoàn toàn với phần cứng
# !pip install "numpy<2" cupy-cuda12x pygit2==1.15.1

# 3. Ép hệ thống khởi động lại để nạp cấu hình mới
import os
os.kill(os.getpid(), 9)
# Out:
# Found existing installation: cupy-cuda12x 14.0.1
# Uninstalling cupy-cuda12x-14.0.1:
#   Successfully uninstalled cupy-cuda12x-14.0.1
# WARNING: Skipping cupy as it is not installed.
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: rembg 2.0.57
# Uninstalling rembg-2.0.57:
#   Successfully uninstalled rembg-2.0.57
# Found existing installation: PyMatting 1.1.15
# Uninstalling PyMatting-1.1.15:
#   Successfully uninstalled PyMatting-1.1.15
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# INFO: pip is looking at multiple versions of cupy-cuda12x to determine which version is compatible with other requirements. This could take a while.
# ...
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 MB 7.9 MB/s eta 0:00:00
# ...

# %%
# Xóa thư mục cũ để làm sạch hoàn toàn
# !rm -rf /content/Fooocus
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git

# Khởi chạy Fooocus và lấy link tạo ảnh
# %cd /content/Fooocus
# !python launch.py --share
# Out:
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6735 (from 1)
# Receiving objects: 100% (6735/6735), 33.35 MiB | 32.52 MiB/s, done.
# Resolving deltas: 100% (3849/3849), done.
# /content/Fooocus
# [System ARGV] ['launch.py', '--share']
# /content/Fooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for rembg: No package metadata was found for rembg
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 13.8MB/s]
# ...
